# %% [markdown]
# ## Estimating the age of abalone

# %% [markdown]
# Determing an abalone'age involves counting the number of rings in a cross-section of the shell through a microscope.
# Since this method is somewhat cumbersome and complex we are estimating the age of the abalone using its physical characteristics.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/abalone.csv')

# %%
df.head()
# Out:
#   sex  length  diameter  height  whole_wt  shucked_wt  viscera_wt  shell_wt  \
# 0   M   0.455     0.365   0.095    0.5140      0.2245      0.1010     0.150
# 1   M   0.350     0.265   0.090    0.2255      0.0995      0.0485     0.070
# 2   F   0.530     0.420   0.135    0.6770      0.2565      0.1415     0.210
# 3   M   0.440     0.365   0.125    0.5160      0.2155      0.1140     0.155
# 4   I   0.330     0.255   0.080    0.2050      0.0895      0.0395     0.055
#
#    rings   age
# 0     15  16.5
# 1      7   8.5
# 2      9  10.5
# 3     10  11.5
# 4      7   8.5

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('darkgrid')
sns.set_palette('colorblind')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         4177 non-null   object
#  1   length      4177 non-null   float64
#  2   diameter    4177 non-null   float64
#  3   height      4177 non-null   float64
#  4   whole_wt    4177 non-null   float64
#  5   shucked_wt  4177 non-null   float64
#  6   viscera_wt  4177 non-null   float64
#  7   shell_wt    4177 non-null   float64
#  8   rings       4177 non-null   int64
#  9   age         4177 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 326.5+ KB

# %% [markdown]
# #### We can see that there are no any null values and rings column contains integer values  and all are float

# %%
df.describe(include='all')
# Out:
#          sex       length     diameter       height     whole_wt   shucked_wt  \
# count   4177  4177.000000  4177.000000  4177.000000  4177.000000  4177.000000
# unique     3          NaN          NaN          NaN          NaN          NaN
# top        M          NaN          NaN          NaN          NaN          NaN
# freq    1528          NaN          NaN          NaN          NaN          NaN
# mean     NaN     0.523992     0.407881     0.139516     0.828742     0.359367
# std      NaN     0.120093     0.099240     0.041827     0.490389     0.221963
# min      NaN     0.075000     0.055000     0.000000     0.002000     0.001000
# 25%      NaN     0.450000     0.350000     0.115000     0.441500     0.186000
# 50%      NaN     0.545000     0.425000     0.140000     0.799500     0.336000
# 75%      NaN     0.615000     0.480000     0.165000     1.153000     0.502000
# max      NaN     0.815000     0.650000     1.130000     2.825500     1.488000
#
# ...

# %% [markdown]
# creating a matrix of scatterplots and histograms for a given DataFrame using 'pairplot'. It allows you to quickly visualize the pairwise relationships between multiple variables in your data.

# %%
data = df.copy()
data.head()
# Out:
#   sex  length  diameter  height  whole_wt  shucked_wt  viscera_wt  shell_wt  \
# 0   M   0.455     0.365   0.095    0.5140      0.2245      0.1010     0.150
# 1   M   0.350     0.265   0.090    0.2255      0.0995      0.0485     0.070
# 2   F   0.530     0.420   0.135    0.6770      0.2565      0.1415     0.210
# 3   M   0.440     0.365   0.125    0.5160      0.2155      0.1140     0.155
# 4   I   0.330     0.255   0.080    0.2050      0.0895      0.0395     0.055
#
#    rings   age
# 0     15  16.5
# 1      7   8.5
# 2      9  10.5
# 3     10  11.5
# 4      7   8.5

# %%
sns.pairplot(data=data,vars=['length','diameter','height','whole_wt','shucked_wt','viscera_wt','shell_wt'],hue='sex',kind='scatter',diag_kind='hist')
